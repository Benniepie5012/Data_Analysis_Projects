# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = "plotly_white"
import kaleido 

data = pd.read_csv("supply_chain_data.csv")
data.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
# Define the number of decimal places to round to
#decimal_places = 2

# Round up the values in the 'Values' column to the specified decimal places
#df['Values'] = df['Values'].round(decimal_places)

# %%
decimal_places = 4
data['Manufacturing costs'] = data['Manufacturing costs'].round(decimal_places)

# %%
decimal_places = 4
data['Costs'] = data['Costs'].round(decimal_places)

decimal_places = 4
data['Revenue generated'] = data['Revenue generated'].round(decimal_places)

decimal_places = 4
data['Price'] = data['Price'].round(decimal_places)

decimal_places = 4
data['Defect rates'] = data['Defect rates'].round(decimal_places)

# %%
data.head()
# Out:
#   Product type   SKU    Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.8080            55                      802
# 1     skincare  SKU1  14.8435            95                      736
# 2     haircare  SKU2  11.3197            34                        8
# 3     skincare  SKU3  61.1633            68                       83
# 4     skincare  SKU4   4.8055            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0          8661.9968            Non-binary            58           7
# 1          7460.9001                Female            53          30
# 2          9577.7496               Unknown             1          10
# 3          7766.8364            Non-binary            23          13
# 4          2686.5052            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# ...

# %%
print(data.describe())
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462456     48.400000               460.990000        5776.048189
# std     31.168190     30.743317               303.780074        2732.841744
# min      1.700000      1.000000                 8.000000        1061.618500
# 25%     19.597825     22.750000               184.250000        2812.847125
# 50%     51.239850     43.500000               392.500000        6006.352050
# 75%     77.198225     75.000000               704.250000        8253.976900
# max     99.171300    100.000000               996.000000        9866.465500
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %%
fig = px.scatter(data, x='Price', y='Revenue generated',
                color='Product type', hover_data=['Number of products sold'], 
                 trendline="ols") 
fig.show("png")

# %%
data.head()
# Out:
#   Product type   SKU    Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.8080            55                      802
# 1     skincare  SKU1  14.8435            95                      736
# 2     haircare  SKU2  11.3197            34                        8
# 3     skincare  SKU3  61.1633            68                       83
# 4     skincare  SKU4   4.8055            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0          8661.9968            Non-binary            58           7
# 1          7460.9001                Female            53          30
# 2          9577.7496               Unknown             1          10
# 3          7766.8364            Non-binary            23          13
# 4          2686.5052            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# ...

# %%
sales_data = data.groupby('Product type')['Number of products sold'].sum().reset_index()

pie_chart = px.pie(sales_data, values= 'Number of products sold',
                  names='Product type', title= 'Sales by Product Type',
                  hover_data = ['Number of products sold'], hole =0.5,
                  color_discrete_sequence=px.colors.qualitative.Pastel)

pie_chart.show("png")

# %%
data.tail()
# Out:
#    Product type    SKU    Price  Availability  Number of products sold  \
# 95     haircare  SKU95  77.9039            65                      672
# 96    cosmetics  SKU96  24.4231            29                      324
# 97     haircare  SKU97   3.5261            56                       62
# 98     skincare  SKU98  19.7546            43                      913
# 99     haircare  SKU99  68.5178            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 95          7386.3639               Unknown            15          14
# 96          7698.4248            Non-binary            67           2
# 97          4370.9166                  Male            46          19
# 98          8525.9526                Female            53           1
# 99          9185.1858               Unknown            55           8
#
#     Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
total_revenue = data.groupby('Shipping carriers')['Revenue generated'].sum().reset_index()

bar_chart = px.bar(total_revenue, x='Shipping carriers', y='Revenue generated',
                   title='Total Revenue by Shipping Carrier')
                

bar_chart.show("png")

# %%
avg_lead_time = data.groupby('Product type')['Lead time'].mean().reset_index()

avg_manufacturing_costs = data.groupby('Product type')['Manufacturing costs'].mean().reset_index()

result = pd.merge(avg_lead_time, avg_manufacturing_costs, on='Product type')

result.rename(columns={'Lead time': 'Average Lead Time', 'Manufacturing costs': 'Average Manufacturing Costs'}, inplace=True)
print(result)
# Out:
#   Product type  Average Lead Time  Average Manufacturing Costs
# 0    cosmetics          13.538462                    43.052742
# 1     haircare          18.705882                    48.457997
# 2     skincare          18.000000                    48.993165

# %%
revenue_chart = px.line(data, x='SKU', 
                        y='Revenue generated', 
                        title='Revenue Generated by SKU')
revenue_chart.show("png")

# %%
stock_chart = px.line(data, x='SKU', 
                      y='Stock levels', 
                      title='Stock Levels by SKU')
stock_chart.show("png")

# %%
order_quantity_chart = px.bar(data, x='SKU', 
                              y='Order quantities', 
                              title='Order Quantity by SKU')
order_quantity_chart.show("png")

# %%
shipping_cost_chart = px.bar(data, x='Shipping carriers', 
                             y='Shipping costs', 
                             title='Shipping Costs by Carrier')
shipping_cost_chart.show('png')

# %%
data.head()
# Out:
#   Product type   SKU    Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.8080            55                      802
# 1     skincare  SKU1  14.8435            95                      736
# 2     haircare  SKU2  11.3197            34                        8
# 3     skincare  SKU3  61.1633            68                       83
# 4     skincare  SKU4   4.8055            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0          8661.9968            Non-binary            58           7
# 1          7460.9001                Female            53          30
# 2          9577.7496               Unknown             1          10
# 3          7766.8364            Non-binary            23          13
# 4          2686.5052            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# ...

# %%
transportation_charts = px.pie(data, 
                               values="Costs", names="Transportation modes",
                               title='Cost Distribution by Transportation mode', 
                               hole=0.5,
                               color_discrete_sequence =px.colors.qualitative.Pastel)

transportation_charts.show("png")

# %%
defect_rates_by_product = data.groupby('Product type')['Defect rates'].mean().reset_index()

fig = px.bar(defect_rates_by_product, x='Product type', y='Defect rates',
             title='Average Defect Rates by Product Type')
fig.show("png")

# %%
pivot_table = pd.pivot_table(data, values='Defect rates', 
                             index=['Transportation modes'], 
                             aggfunc='mean')
print(pivot_table)
# Out:
#                       Defect rates
# Transportation modes
# Air                       1.823935
# Rail                      2.318807
# Road                      2.620945
# Sea                       2.315282

# %%
transportation_chart = px.pie(values=pivot_table["Defect rates"], 
                              names=pivot_table.index, 
                              title='Defect Rates by Transportation Mode',
                              hole=0.5,
                              color_discrete_sequence=px.colors.qualitative.Pastel)

transportation_chart.show('png')
